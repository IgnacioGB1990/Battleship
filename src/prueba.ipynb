# %%
import numpy as np
import random

# %%
# 1
tablero = np.full((10,10)," ")
matriz = tablero

# 2 
# Barco de 2 posiciones de eslora
# tablero[0,1]="O"
# tablero[1,1]="O"

# Barco de 4 posiciones de eslora
# tablero[1,3]="O"
# tablero[1,4]="O"
# tablero[1,5]="O"
# tablero[1,6]="O"


#Dummy data
# tablero[8,0]="O"
# tablero[9,0]="O"


#print(tablero)
# Continua más abajo...

# 3 Recibe disparo a un barco
# if tablero[0,1]=="O":
#     tablero[0,1]="X"

    #print("Has dado a un barco!")
    #print(tablero)

# 4 Recibe un disparo al agua
# if tablero[0,0]==" ":
#     tablero[0,0]="-"

    #print("Disparo al agua!")
    #print(tablero)

# 5

# 5.1 Generamos coordenada de origen aleatoria
x = random.randint(0,9)
y = random.randint(0,9)

print("Intentamos plantar barco en las coordenadas: ",x,y)
# tablero[ x, y ] = "*"

# 5.2 Generar un punto cardinal aleatorio (N, S, W, E)

cardinal_aleatorio = np.random.choice(["N","S","W","E"], size=1)
#print(cardinal_aleatorio)

# Vamos a ir dirección Sur 4 elementos empezando por ejemplo 0,3 
# para toparnos con el barco de tamaño 4 que ya tenemos
# Luego nuestras coordenadas iniciales serían:
# x = 4
# y = 0

boat_size = 4
start_x = x - boat_size
stop_x = x + boat_size

stop_y = y + boat_size

#slice_tablero_sur = tablero[0:4,3:4]

# Por mucho que se vaya a la derecho no pasa nada. y como máximo será 9 y aunque delimites 9+1 = 10 slicing te coge última columna
# DIRECCIÓN SUR => PROBLEMA CUANDO ESTÁ
slice_tablero = tablero[ x:stop_x, y:y+1 ]


# slice_tablero = tablero[1:2,3:7]
# print(slice_tablero)

# Indica cada elemento de un slice. De prueba de momento.
def indica(slice):
    for boat in np.nditer(slice):
        if boat == "O":
            print("Barco encontrado!")
        elif boat == "-":
            print("Disparo fallido!")
        elif boat =="X":
            print("Te has topado con un barco tocado")
        else:
            print("Agua!")



# N O R T H
def check_north(start_x,slice_tablero,x,y):
    if x<3:
        print("Lo siento pero te sales del tablero!")
    else:
        check_boat_position_available_north(start_x,slice_tablero,x,y)

def check_boat_position_available_north(start_x,slice,x,y): 
    for boat in np.nditer(slice):
        if boat == "O":
            print("Ya existe un barco!")
            break
    else:
        tablero[ start_x:x, y:y+1 ]="O"
        print("Coast is clear")  

# S O U T H
def check_boat_position_available_south(stop_x,slice,x,y): 
    for boat in np.nditer(slice):
        if boat == "O":
            print("Ya existe un barco!")
            break
    else:
        tablero[ x:stop_x, y:y+1 ]="O"
        print("Coast is clear")

            

def check_south(stop_x,slice_tablero,x,y):
    if stop_x>10:
        print("Lo siento pero te sales del tablero!")
    else:
        check_boat_position_available_south(stop_x,slice_tablero,x,y)


# E A S T
def check_boat_position_available_east(stop_y,slice,x,y): 
    for boat in np.nditer(slice):
        if boat == "O":
            print("Ya existe un barco!")
            break
    else:
        tablero[ x:x+1, y:stop_y ]="O"
        print("Coast is clear")

def check_east(stop_y,slice_tablero,x,y):
    if stop_y<8:
        print("Lo siento pero te sales del tablero!")
    else:
        check_boat_position_available_east(stop_y,slice_tablero,x,y)


# if cardinal_aleatorio == "S":
#check_south(stop_x,slice_tablero,x,y)
#check_north(start_x,slice_tablero,x,y)
check_east(stop_y,slice_tablero,x,y)





print()
print(tablero)
# Out:
# Intentamos plantar barco en las coordenadas:  5 9
# Coast is clear
#
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' 'O']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']]
